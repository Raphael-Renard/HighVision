# %%
import torch

if torch.cuda.is_available():
    print("CUDA is available")
    device = torch.device("cuda")
    print(f"Device: {torch.cuda.get_device_name(0)}")
else:
    print("CUDA is not available")

x = torch.rand(5, 5).to(device)
y = torch.rand(5, 5).to(device)
z = x + y

print("x:", x)
print("y:", y)
print("z (x + y):", z)

print(torch.cuda.is_available())
# Out:
# CUDA is available
# Device: NVIDIA RTX A3000 Laptop GPU
# x: tensor([[0.1511, 0.9154, 0.8206, 0.1567, 0.7936],
#         [0.5672, 0.2826, 0.4143, 0.8961, 0.3274],
#         [0.4316, 0.9035, 0.9005, 0.9850, 0.0901],
#         [0.8573, 0.0050, 0.0783, 0.2722, 0.2322],
#         [0.6851, 0.1265, 0.2155, 0.2212, 0.9059]], device='cuda:0')
# y: tensor([[6.8647e-01, 6.2636e-01, 8.0513e-01, 8.0352e-02, 2.0961e-01],
#         [6.0436e-01, 5.3168e-01, 5.7454e-01, 1.6165e-04, 2.2292e-03],
#         [8.5861e-01, 9.5859e-01, 6.4982e-01, 3.8100e-01, 4.8173e-01],
#         [3.6399e-01, 5.7518e-02, 2.9005e-02, 8.4116e-01, 6.6323e-01],
#         [7.9446e-01, 7.5704e-01, 3.3520e-02, 5.6896e-01, 4.9209e-01]],
#        device='cuda:0')
# z (x + y): tensor([[0.8376, 1.5418, 1.6257, 0.2370, 1.0032],
#         [1.1715, 0.8143, 0.9888, 0.8963, 0.3297],
#         [1.2902, 1.8621, 1.5503, 1.3660, 0.5719],
#         [1.2213, 0.0625, 0.1073, 1.1134, 0.8955],
#         [1.4796, 0.8835, 0.2491, 0.7902, 1.3980]], device='cuda:0')
# True
