# %%
import sys
path = "../.."
if path not in sys.path:
    sys.path.insert(0, path)

# %%
import cv2 as cv
import os
from data_retrieval import lipade_groundtruth
from absolute_path import absolutePath

corpus = "lipade_groundtruth"

# %% [markdown]
# cv2 can read images that appear full white with PIL.image (with a "corrupted" warning, removed by saving the result)

# %%
paths,_,y = lipade_groundtruth.getDataset(mode="unique")

errors = []
for i in range(len(paths)):
    try :
        cv.imwrite(paths[i], cv.imread(paths[i]))
    except:
        errors.append(paths[i])
# Out:
# Corrupt JPEG data: premature end of data segment
# [ERROR:0@52.587] global loadsave.cpp:507 imread_ imread_('/home/samuel-g/Documents/HighVision/highvision/corpus/lipade_groundtruth/unique/pho_2K47161_59_02.jpg'): can't read data: OpenCV(4.11.0) /io/opencv/modules/imgcodecs/src/loadsave.cpp:501: error: (-2:Unspecified error) in function 'bool cv::imread_(const String&, int, cv::OutputArray)'
# > Internal imread issue:
# >     'original_ptr == real_mat.data' must be 'true'
#
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 4 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 6 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 1 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 5 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 4 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 4 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 4 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 4 extraneous bytes before marker 0xd9
# [ERROR:0@116.787] global loadsave.cpp:507 imread_ imread_('/home/samuel-g/Documents/HighVision/highvision/corpus/lipade_groundtruth/unique/pho_2K47161_04_02.jpg'): can't read data: OpenCV(4.11.0) /io/opencv/modules/imgcodecs/src/loadsave.cpp:501: error: (-2:Unspecified error) in function 'bool cv::imread_(const String&, int, cv::OutputArray)'
# > Internal imread issue:
# >     'original_ptr == real_mat.data' must be 'true'
#
# Corrupt JPEG data: 3 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 4 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 4 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 1 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 6 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 3 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 4 extraneous bytes before marker 0xd9
# [ERROR:0@242.789] global loadsave.cpp:507 imread_ imread_('/home/samuel-g/Documents/HighVision/highvision/corpus/lipade_groundtruth/unique/pho_2K47161_03_03.jpg'): can't read data: OpenCV(4.11.0) /io/opencv/modules/imgcodecs/src/loadsave.cpp:501: error: (-2:Unspecified error) in function 'bool cv::imread_(const String&, int, cv::OutputArray)'
# > Internal imread issue:
# >     'original_ptr == real_mat.data' must be 'true'
#
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 7 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 2 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 2 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 1 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: 7 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 6 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment
# Corrupt JPEG data: premature end of data segment

# %%
for error in errors:
    path = error.split("/")
    prefix = absolutePath + "corpus/" + corpus + "/"
    os.rename(prefix + path[-2] + "/" + path[-1], prefix + "corrupted/" + path[-1])

# %%
path = "../../corpus/" + corpus + "/corrupted/"
i = 0

print(path + os.listdir(path)[i])
print(cv.imread(path + os.listdir(path)[i]))
# Out:
# ../../corpus/lipade_groundtruth/corrupted/2K2476_07_01.jpg
# None
