# %%
import sys
path = "../.."
if path not in sys.path:
    sys.path.insert(0, path)

# %%
from data_retrieval.tools.uniformize_image import uniformize_image
from data_retrieval.lipade_groundtruth import getDataset
from absolute_path import absolutePath
from PIL import Image

N = 512

# %%
x,_,_ = getDataset(mode="all")

for path in x:
    # remove "corpus/"
    relative = path[len(absolutePath):].split("/")
    relative = "/".join(relative[1:])

    im = uniformize_image(path, N)

    Image.fromarray(im).save(absolutePath + "mini_corpus/" + relative)
# Out:
# /home/samuel-g/.pyenv/versions/3.11.11/lib/python3.11/site-packages/PIL/TiffImagePlugin.py:935: UserWarning: Corrupt EXIF data.  Expecting to read 2 bytes but only got 0.
#   warnings.warn(str(msg))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 8
#       5 relative = path[len(absolutePath):].split("/")
#       6 relative = "/".join(relative[1:])
# ----> 8 im = uniformize_image(path, N)
#      10 Image.fromarray(im).save(absolutePath + "mini_corpus/" + relative)
#
# File ~/Documents/HighVision/highvision/data_retrieval/tools/../../data_retrieval/tools/uniformize_image.py:10, in uniformize_image(image_path, size)
#       9 def uniformize_image(image_path, size):
# ---> 10     image = Image.open(image_path)
#      11     image_array = np.array(image)
#      13     if len(image_array.shape) == 2:
#
# File ~/.pyenv/versions/3.11.11/lib/python3.11/site-packages/PIL/Image.py:3515, in open(fp, mode, formats)
#    3512             raise
#    3513     return None
# -> 3515 im = _open_core(fp, filename, prefix, formats)
#    3517 if im is None and formats is ID:
#    3518     checked_formats = ID.copy()
#
# File ~/.pyenv/versions/3.11.11/lib/python3.11/site-packages/PIL/Image.py:3503, in open.<locals>._open_core(fp, filename, prefix, formats)
#    3501 elif result:
#    3502     fp.seek(0)
# -> 3503     im = factory(fp, filename)
#    3504     _decompression_bomb_check(im.size)
#    3505     return im
#
# File ~/.pyenv/versions/3.11.11/lib/python3.11/site-packages/PIL/TiffImagePlugin.py:1153, in TiffImageFile.__init__(self, fp, filename)
#    1150 self.tag: ImageFileDirectory_v1
#    1151 """ Legacy tag entries """
# -> 1153 super().__init__(fp, filename)
#
# File ~/.pyenv/versions/3.11.11/lib/python3.11/site-packages/PIL/ImageFile.py:144, in ImageFile.__init__(self, fp, filename)
#     142 try:
#     143     try:
# --> 144         self._open()
#     145     except (
#     146         IndexError,  # end of data
#     147         TypeError,  # end of data (ord)
#    (...)
#     150         struct.error,
#     151     ) as v:
#     152         raise SyntaxError(v) from v
#
# File ~/.pyenv/versions/3.11.11/lib/python3.11/site-packages/PIL/TiffImagePlugin.py:1177, in TiffImageFile._open(self)
#    1174 logger.debug("- ifh: %s", repr(ifh))  # Use repr to avoid str(bytes)
#    1176 # and load the first frame
# -> 1177 self._seek(0)
#
# File ~/.pyenv/versions/3.11.11/lib/python3.11/site-packages/PIL/TiffImagePlugin.py:1248, in TiffImageFile._seek(self, frame)
#    1246 self.tag = self.ifd = ImageFileDirectory_v1.from_v2(self.tag_v2)
#    1247 self.__frame = frame
# -> 1248 self._setup()
#
# File ~/.pyenv/versions/3.11.11/lib/python3.11/site-packages/PIL/TiffImagePlugin.py:1426, in TiffImageFile._setup(self)
#    1424 if not isinstance(xsize, int) or not isinstance(ysize, int):
#    1425     msg = "Invalid dimensions"
# -> 1426     raise ValueError(msg)
#    1427 self._tile_size = xsize, ysize
#    1428 orientation = self.tag_v2.get(ExifTags.Base.Orientation)
#
# ValueError: Invalid dimensions
